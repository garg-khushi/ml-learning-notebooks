# %%
# Install TensorFlow
# !pip install tensorflow==2.16.2

import tensorflow as tf 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, Dense 
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='tensorflow')
# Out:
# Requirement already satisfied: tensorflow==2.16.2 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (2.32.5)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (1.75.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorflow==2.16.2) (1.26.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2) (0.45.1)
# Requirement already satisfied: rich in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (14.1.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (0.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/myenv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2) (0.1.2)

# %%
import numpy as np
#define layer
#Input(shape=(20,)) creates an input layer that expects input vectors of length 20.
input_layer=Input(shape=(20,))
print(input_layer)
# Out:
# <KerasTensor shape=(None, 20), dtype=float32, sparse=False, ragged=False, name=keras_tensor_7>

# %%
hidden_layer1=Dense(64,activation='relu')(input_layer)
hidden_layer2 = Dense(64, activation='relu')(hidden_layer1)
#Dense(64, activation='relu') creates a dense (fully connected) layer with 64 units and ReLU activation function.

#Each hidden layer takes the output of the previous layer as its input.

# %%
output_layer = Dense(1, activation='sigmoid')(hidden_layer2) 
#Finally, you will define the output layer. Suppose you are working on a binary classification problem, so the output layer will have one unit with a sigmoid activation function

# %%
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()
#create model by specifying input and output layers
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Example test data (in practice, use real dataset) 

X_test = np.random.rand(200, 20) 
y_test = np.random.randint(2, size=(200, 1)) 
loss, accuracy = model.evaluate(X_test, y_test) 
print(f'Test loss: {loss}') 
print(f'Test accuracy: {accuracy}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5084 - loss: 0.7050
# Test loss: 0.7090367674827576
# Test accuracy: 0.5

# %%
from tensorflow.keras.layers import Dropout, Dense, Input
from tensorflow.keras.models import Model

input_layer=Input(shape=(20,))
hidden_layer = Dense(64, activation='relu')(input_layer)
dropout_layer=Dropout(rate=0.5)(hidden_layer)
hidden_layer2= Dense(64, activation='relu')(dropout_layer)
output_layer=Dense(1,activation='sigmoid')(hidden_layer2)
model=Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.layers import Dropout, Dense, Input
from tensorflow.keras.models import Model

input_layer=Input(shape=(20,))
hidden_layer = Dense(64, activation='relu')(input_layer)
batch_norm_layer = BatchNormalization()(hidden_layer)
hidden_layer2= Dense(64, activation='relu')(batch_norm_layer)
output_layer=Dense(1,activation='sigmoid')(hidden_layer2)
model=Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,825 (22.75 KB)
#  Trainable params: 5,697 (22.25 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
from tensorflow.keras.layers import Dropout, Dense, Input
from tensorflow.keras.models import Model

input_layer=Input(shape=(20,))
hidden_layer = Dense(64, activation='relu')(input_layer)
dropout_layer=Dropout(rate=0.5)(hidden_layer)
hidden_layer2 = Dense(64, activation='relu')(dropout1)
dropout2 = Dropout(0.5)(hidden_layer2)

# Define the output layer
output_layer = Dense(1, activation='sigmoid')(dropout2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       5 hidden_layer = Dense(64, activation='relu')(input_layer)
#       6 dropout_layer=Dropout(rate=0.5)(hidden_layer)
# ----> 7 hidden_layer2 = Dense(64, activation='relu')(dropout1)
#       8 dropout2 = Dropout(0.5)(hidden_layer2)
#      10 # Define the output layer
#
# NameError: name 'dropout1' is not defined

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# Define the input layer
input_layer = Input(shape=(20,))

# Add hidden layers with Tanh activation
hidden_layer1 = Dense(64, activation='tanh')(input_layer)
hidden_layer2 = Dense(64, activation='tanh')(hidden_layer1)

# Define the output layer
output_layer = Dense(1, activation='sigmoid')(hidden_layer2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 22
#      19 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      21 # Train the model
# ---> 22 model.fit(X_train, y_train, epochs=10, batch_size=32)
#      24 # Evaluate the model
#      25 loss, accuracy = model.evaluate(X_test, y_test)
#
# NameError: name 'X_train' is not defined

# %%
from tensorflow.keras.layers import BatchNormalization

# Define the input layer
input_layer = Input(shape=(20,))

# Add hidden layers with batch normalization
hidden_layer1 = Dense(64, activation='relu')(input_layer)
batch_norm1 = BatchNormalization()(hidden_layer1)
hidden_layer2 = Dense(64, activation='relu')(batch_norm1)
batch_norm2 = BatchNormalization()(hidden_layer2)

# Define the output layer
output_layer = Dense(1, activation='sigmoid')(batch_norm2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,081 (23.75 KB)
#  Trainable params: 5,825 (22.75 KB)
#  Non-trainable params: 256 (1.00 KB)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 23
#      20 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      22 # Train the model
# ---> 23 model.fit(X_train, y_train, epochs=10, batch_size=32)
#      25 # Evaluate the model
#      26 loss, accuracy = model.evaluate(X_test, y_test)
#
# NameError: name 'X_train' is not defined
